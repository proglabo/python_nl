# %% [markdown]
# # 単語と文章のベクトル化
#
# 自然言語のままで各種分析を行う際は、単語と文章のベクトル化が必要になります。
#
# 単語のベクトル化：word2vec
#
# 文章のベクトル化：doc2vec
#
#
# # 学習済みモデル
#
# 基本的に、word2vecは、著名な学習済みデータセットを使用することが多いです。
#
# doc2vecは、案件ごとに学習することが多いです。
#
# http://blog.hassaku-labs.com/post/pretrained-word2vec/
#
# ＊学習済みモデルの「entity_vector.model.bin」は、下記URLよりダウンロードしておいてください。
#
# http://www.cl.ecei.tohoku.ac.jp/~m-suzuki/jawiki_vector/

# %% [markdown]
# # word2vec（既存モデルの使用）

# %%
# 読み込み
from gensim.models import KeyedVectors
model = KeyedVectors.load_word2vec_format('./data/entity_vector.model.bin', binary=True)

# %%
# 単語のベクトル化
model.wv["イチロー"]
# Out:
# c:\python37\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
# array([ 0.09032071, -0.05341686,  0.28220174,  0.29330444,  0.05328318,
#         0.14241028, -0.24687128,  0.18441112,  0.02650695,  0.0828563 ,
#        -0.426362  , -0.02014246,  0.02603034, -0.03726895,  0.19294073,
#        -0.12511627,  0.5407648 ,  0.05329642, -0.114064  , -0.08794833,
#         0.48768535,  0.16046745,  0.0785282 , -0.49404824,  0.11478704,
#        -0.32564625, -0.55675274, -0.30036446, -0.20920439,  0.06128695,
#        -0.05599485, -0.08785352, -0.17117216,  0.28584853,  0.01225359,
#         0.15091456, -0.07321789, -0.07828152,  0.16382505,  0.38058066,
#         0.19476666,  0.06204469, -0.27429718,  0.04294476, -0.05257293,
#         0.05322105, -0.15351981, -0.6151462 ,  0.16540758,  0.36411384,
#         0.03025797, -0.31749636,  0.2605783 , -0.05329959,  0.0940825 ,
#        -0.1286651 , -0.19278173, -0.3219691 ,  0.10385962,  0.25326288,
#        -0.00975231, -0.09564543, -0.3629564 , -0.20086282, -0.12936008,
#         0.43610513, -0.36885667,  0.295815  , -0.12997843,  0.4314916 ,
#        -0.14947411,  0.06331145,  0.01181818,  0.6452983 , -0.06020614,
#         0.05043695, -0.04708637,  0.01179598, -0.36667073, -0.17686577,
#         0.17143977,  0.3592317 ,  0.3453721 , -0.11092807,  0.03805619,
#         0.11667155, -0.21518715, -0.19824842,  0.7911886 , -0.28698277,
#         0.22000696,  0.6519969 ,  0.08775561, -0.03462984, -0.06396964,
#         0.10759465, -0.27445945,  0.12017197,  0.2182324 ,  0.02001271,
#        -0.2749907 ,  0.1472141 , -0.15745465, -0.36727196,  0.03987442,
#        -0.15021245, -0.12411412,  0.47442573, -0.27764642,  0.18471095,
#        -0.19148739,  0.4019693 ,  0.04580771, -0.01343833,  0.05986825,
#        -0.0702235 , -0.3262036 ,  0.21441376, -0.05585141,  0.4068481 ,
#        -0.20326735,  0.159737  ,  0.22966705, -0.2549111 , -0.38730478,
#        -0.2007898 , -0.12139512, -0.13236366, -0.1494875 , -0.8284076 ,
#         0.14567637, -0.14218427, -0.20600604, -0.02710883, -0.7757116 ,
#        -0.23637761, -0.28013197,  0.03547173,  0.08473831, -0.24143983,
#         0.5714134 , -0.20404778,  0.2857376 , -0.12174043, -0.05783201,
#         0.16254428, -0.11809638,  0.45789692,  0.567776  ,  0.1777195 ,
#        -0.4642111 ,  0.12196863, -0.25125453, -0.02837646, -0.11756613,
#        -0.27768514, -0.06383181, -0.13533409, -0.09328051,  0.01945806,
#        -0.04140085, -0.13909361,  0.08832241, -0.5650386 , -0.13418637,
#         0.01655536, -0.27362147, -0.12080104,  0.20296168,  0.02414615,
#         0.02504183, -0.20633349,  0.03708602,  0.26493123, -0.03714316,
#         0.23291802,  0.1900764 ,  0.5301852 ,  0.3596682 ,  0.06676093,
#         0.18211949,  0.01261326, -0.01917026,  0.00164132, -0.08637996,
#        -0.03631896,  0.6470705 ,  0.0400873 , -0.08204225,  0.15705019,
#        -0.06294098, -0.09003455,  0.09688611,  0.2371008 , -0.04234828,
#         0.12725645,  0.11786682, -0.5076251 ,  0.3587788 , -0.19403741],
#       dtype=float32)

# %%
# 類似単語の抽出
results = model.most_similar(u"[指原莉乃]")
for result in results:
    print(result)
# Out:
# ('[前田敦子]', 0.8524860143661499)
# ('[松井玲奈]', 0.8497596979141235)
# ('[柏木由紀]', 0.8481603860855103)
# ('[大島優子]', 0.8426693677902222)
# ('[渡辺麻友]', 0.836478590965271)
# ('[高橋みなみ]', 0.8302541971206665)
# ('[山本彩]', 0.8275360465049744)
# ('[HKT48]', 0.8238900899887085)
# ('[小嶋陽菜]', 0.8218119144439697)
# ('[島崎遥香]', 0.8172259330749512)

# %%
# 減算
results = model.most_similar(positive=[u'[妻]'],negative=[u'[愛人]'])
for result in results:
    print(result)
# Out:
# ('ドレナージ', 0.4027651846408844)
# ('[分娩]', 0.3961508870124817)
# ('[座位]', 0.37961751222610474)
# ('[出産]', 0.37935060262680054)
# ('[生殖]', 0.3761950731277466)
# ('望ましい', 0.37324926257133484)
# ('[子育て]', 0.372659832239151)
# ('[歯科医師]', 0.3716592788696289)
# ('[歯学者]', 0.36931663751602173)
# ('[公認心理師]', 0.36690229177474976)

# %%
# 加算
results = model.most_similar(positive=[u'[妖精]',u'[悪]'])
for result in results:
    print(result)
# Out:
# ('[精霊]', 0.8402377367019653)
# ('[魔女]', 0.8217898607254028)
# ('[悪魔]', 0.8189244270324707)
# ('悪霊', 0.8049401044845581)
# ('創造主', 0.7825872898101807)
# ('[吸血鬼]', 0.7805193662643433)
# ('[悪霊]', 0.779639482498169)
# ('精霊', 0.7730634212493896)
# ('魔物', 0.771123468875885)
# ('[エルフ]', 0.7656500339508057)

# %%
# 加算減算
results = model.most_similar(positive=[u'[イチロー]',u'[サッカー]'],negative=[u'[野球]'])
for result in results:
    print(result)
# Out:
# ('[ロナウド]', 0.6781752109527588)
# ('[ジネディーヌ・ジダン]', 0.6686528325080872)
# ('[中田英寿]', 0.6643422842025757)
# ('[ジーコ]', 0.6631736755371094)
# ('[ロベルト・バッジョ]', 0.6589246988296509)
# ('[ロナウジーニョ]', 0.6574504971504211)
# ('[ディエゴ・マラドーナ]', 0.6535028219223022)
# ('ジダン', 0.6474759578704834)
# ('[デビッド・ベッカム]', 0.6473382115364075)
# ('[三浦知良]', 0.6451823711395264)

# %% [markdown]
# # doc2vec（自己学習）
#
# 使用するデータは、青空文庫にある小説です。
#
# https://www.aozora.gr.jp/cards/000148/files/794_ruby_4237.zip

# %%
# データの読み込み
with open('./data/sanshiro.txt', encoding='sjis') as file:
    text = file.read()

# ファイル整形
import re
text = re.split('\-{5,}',text)[2]
text = re.split('底本：',text)[0]
text = text.replace('|', '')
text = re.sub('《.+?》', '', text)
text = re.sub('［＃.+?］', '',text)
text = re.sub('\n\n', '\n', text) 
text = re.sub('\r', '', text)
text = re.sub('　', '', text)
text = re.sub(' ', '', text)

print(text[:100])

print(len(text))
# Out:
# 一
# うとうととして目がさめると女はいつのまにか、隣のじいさんと話を始めている。このじいさんはたしかに前の前の駅から乗ったいなか者である。発車まぎわに頓狂な声を出して駆け込んで来て、いきなり肌をぬいだ
# 171110

# %%
# 下記のようなリストに変換する
# [
#  [単語1,単語2,....]
#  [単語1,単語2,....]
#  [単語1,単語2,....]
# ]

# ライブラリの読み込み
from janome.tokenizer import Tokenizer
def extract_data(text):
    '''文章を渡したら、動詞と名詞のリストを返す
    引数：
    　text：一文
    返り値：
    　data：動詞と名詞のリスト
    処理概要：
    　1つの文章を受け取り、その中に含まれている名詞と動詞のリストを返す
    '''
    # インスタンス化
    t = Tokenizer()
    # 動詞と名詞のリスト
    data=[]
    # 形態素解析
    res = t.tokenize(text)
    for i in res:
        data.append(i.surface)
    return data

# テキストを「。」で区切る
text_list = text.split('。')

# それぞれの文章を単語リストに変換(処理に数分かかります)
word_list = [extract_data(text) for text in text_list]

# %%
# 形式の確認
print(len(word_list))

print(word_list[0])
# Out:
# 5904
# ['一', '\n', 'うとうと', 'と', 'し', 'て', '目', 'が', 'さめる', 'と', '女', 'は', 'いつのまにか', '、', '隣', 'の', 'じいさん', 'と', '話', 'を', '始め', 'て', 'いる']

# %%
# ライブラリ読み込み
from gensim.models.doc2vec import Doc2Vec
from gensim.models.doc2vec import TaggedDocument

# %%
# 学習用データに変換
training_docs = []

for i in word_list:
    training_docs.append(
        TaggedDocument(words=i,tags=[str(i)])
    )

# %%
# モデルの学習
model = Doc2Vec(documents=training_docs, dm = 1, size=30, window=8, min_count=1, workers=4)

# %%
# 文章のベクトル化
model.wv[word_list[0]],model.wv[word_list[0]].shape
# Out:
# (array([[-1.19091141e+00, -7.98784614e-01, -1.08580160e+00,
#          -7.86014855e-01,  8.11349332e-01, -7.95187116e-01,
#           1.51691806e+00, -1.77765715e+00, -4.65694129e-01,
#           2.31543827e+00, -2.23256886e-01, -2.00391245e+00,
#           9.84670967e-02,  3.19117680e-02, -1.60752189e+00,
#          -1.94346404e+00, -1.58391857e+00,  1.64841223e+00,
#          -1.67279387e+00, -1.41362178e+00, -1.49163628e+00,
#           9.50311184e-01, -3.27118337e-01,  9.72959459e-01,
#           1.17340267e+00,  1.55865654e-01, -1.15609550e+00,
#          -2.14889550e+00, -1.62270463e+00,  1.17871177e+00],
#         [-6.08448088e-01,  1.36126018e+00, -1.40350032e+00,
#          -5.35801232e-01,  1.14420462e+00,  9.97487307e-01,
#           1.31184554e+00,  1.54259712e-01,  2.16970658e+00,
#           1.58904159e+00,  1.01510954e+00, -2.66622043e+00,
#          -1.26174271e+00, -1.62116277e+00, -1.80827916e+00,
#          -3.24738717e+00, -4.01602447e-01, -1.21021681e-01,
#          -3.89945722e+00,  6.38427883e-02, -6.69850051e-01,
#           8.50056469e-01, -3.26175660e-01,  6.53058231e-01,
#           1.81661212e+00, -1.69530964e+00, -1.09747005e+00,
#          -1.98378849e+00, -8.61174405e-01,  2.90560246e+00],
#         [-1.54039282e-02, -4.92948107e-03, -2.58347820e-02,
#           2.60635163e-03,  2.46539917e-02,  4.92603006e-03,
#           3.00281309e-02,  3.39136273e-03,  6.98657567e-03,
#           1.38206016e-02, -1.27250385e-02, -3.66751626e-02,
#          -4.09252942e-03, -9.67343431e-03, -3.10892202e-02,
#          -2.54398733e-02, -9.65606328e-03,  9.79872048e-03,
#          -3.20700668e-02,  8.96163401e-04, -5.75887598e-03,
#           1.41550247e-02, -7.41566764e-04, -4.28400887e-03,
#           2.06622425e-02, -5.91750839e-04, -2.81482805e-02,
#          -1.05295619e-02, -2.51618363e-02,  6.75129564e-03],
#         [-1.07183003e+00, -1.69234700e-03, -1.28575432e+00,
#          -6.60598576e-01,  9.45343196e-01, -1.94241658e-01,
#           1.54724336e+00, -1.27931249e+00,  5.75074792e-01,
#           2.19193840e+00,  2.52034515e-01, -2.49366689e+00,
#          -3.91161680e-01, -5.43481171e-01, -1.82254779e+00,
#          -2.54014349e+00, -1.30179405e+00,  1.11600983e+00,
#          -2.61410356e+00, -9.61574674e-01, -1.27499807e+00,
#           9.86909688e-01, -4.02682900e-01,  8.72045100e-01,
#           1.48990095e+00, -5.84706426e-01, -1.26830053e+00,
#          -2.26867533e+00, -1.47027659e+00,  1.95947564e+00],
#         [-1.14793324e+00, -5.88839114e-01, -1.11176360e+00,
#          -7.68740535e-01,  7.20972538e-01, -6.32740676e-01,
#           1.51869392e+00, -1.66074252e+00, -2.25534365e-01,
#           2.14427042e+00, -1.87752470e-01, -2.27280951e+00,
#           4.29634191e-02, -1.08812198e-01, -1.60451484e+00,
#          -1.92824280e+00, -1.49299634e+00,  1.55546606e+00,
#          -1.85978580e+00, -1.13325632e+00, -1.41043246e+00,
#           9.81124699e-01, -3.45183611e-01,  9.15187836e-01,
#           1.16381013e+00, -2.39194762e-02, -1.22193933e+00,
#          -2.22316861e+00, -1.62283659e+00,  1.43013513e+00],
#         [-1.24874508e+00, -8.35866868e-01, -1.20791078e+00,
#          -8.51474106e-01,  7.29071319e-01, -7.39030421e-01,
#           1.62669742e+00, -1.94375765e+00, -5.42482734e-01,
#           2.38263226e+00, -2.98356473e-01, -2.47499228e+00,
#           1.52361020e-01,  1.43591076e-01, -1.62675118e+00,
#          -1.92116821e+00, -1.52199459e+00,  1.84234595e+00,
#          -1.79462540e+00, -1.28822303e+00, -1.60672557e+00,
#           1.14720869e+00, -3.01510304e-01,  1.06635237e+00,
#           1.15248930e+00,  9.63630602e-02, -1.41342819e+00,
#          -2.43161368e+00, -1.84416354e+00,  1.49075603e+00],
#         [-7.77515173e-01, -6.16385102e-01, -6.42989635e-01,
#          -4.68060225e-01,  5.11766255e-01, -6.11519575e-01,
#           9.65477109e-01, -1.20541990e+00, -3.38927209e-01,
#           1.47503579e+00, -1.96603522e-01, -1.12654757e+00,
#           1.54336035e-01,  6.91505149e-02, -1.00151896e+00,
#          -1.17105055e+00, -1.04237783e+00,  1.16365802e+00,
#          -9.14848685e-01, -9.78930354e-01, -9.75288808e-01,
#           6.49052322e-01, -2.56546497e-01,  6.24916792e-01,
#           7.67488420e-01,  2.11756870e-01, -7.60924876e-01,
#          -1.30734837e+00, -9.95386183e-01,  6.81807876e-01],
#         [-1.23378050e+00, -6.24197721e-01, -1.22616315e+00,
#          -8.49492252e-01,  8.77547741e-01, -6.74079955e-01,
#           1.64897716e+00, -1.81199014e+00, -1.19418211e-01,
#           2.37025452e+00, -1.46533042e-01, -2.36975813e+00,
#          -5.60746621e-03, -1.52731389e-01, -1.85393298e+00,
#          -2.16013455e+00, -1.71426368e+00,  1.66313195e+00,
#          -2.03072739e+00, -1.37766182e+00, -1.52750385e+00,
#           1.00938284e+00, -3.68658483e-01,  9.79775071e-01,
#           1.27471197e+00, -2.29977034e-02, -1.25802159e+00,
#          -2.39107537e+00, -1.67618847e+00,  1.55103016e+00],
#         [-3.49822734e-03,  3.90683254e-03, -1.55852707e-02,
#          -2.63008149e-03,  1.53426686e-03, -1.27428556e-02,
#           1.76301766e-02, -6.37076376e-03, -1.54800331e-02,
#           8.94151907e-03, -1.33057106e-02, -1.25415968e-02,
#          -9.94064193e-03,  8.25728104e-03,  1.05592291e-04,
#          -1.19408518e-02, -6.65971544e-04, -4.46490565e-04,
#          -1.23692257e-02,  1.19117135e-02, -7.07731862e-03,
#          -8.39350687e-04, -1.42278112e-02, -4.45340993e-03,
#           8.50620307e-03,  9.15375724e-03,  1.36185614e-02,
#           6.49790652e-03,  1.01762405e-02, -1.58758312e-02],
#         [-1.07183003e+00, -1.69234700e-03, -1.28575432e+00,
#          -6.60598576e-01,  9.45343196e-01, -1.94241658e-01,
#           1.54724336e+00, -1.27931249e+00,  5.75074792e-01,
#           2.19193840e+00,  2.52034515e-01, -2.49366689e+00,
#          -3.91161680e-01, -5.43481171e-01, -1.82254779e+00,
#          -2.54014349e+00, -1.30179405e+00,  1.11600983e+00,
#          -2.61410356e+00, -9.61574674e-01, -1.27499807e+00,
#           9.86909688e-01, -4.02682900e-01,  8.72045100e-01,
#           1.48990095e+00, -5.84706426e-01, -1.26830053e+00,
#          -2.26867533e+00, -1.47027659e+00,  1.95947564e+00],
#         [-8.57850969e-01, -4.03427333e-01, -8.71329725e-01,
#          -5.76940954e-01,  6.99689448e-01, -4.43889767e-01,
#           1.21316123e+00, -1.15815270e+00,  3.85123044e-02,
#           1.74410164e+00, -6.82300404e-02, -1.55088329e+00,
#          -4.00724858e-02, -2.10838884e-01, -1.29658663e+00,
#          -1.69162548e+00, -1.08009291e+00,  1.14124167e+00,
#          -1.58894885e+00, -9.79006290e-01, -1.09719872e+00,
#           7.88915336e-01, -3.01537812e-01,  7.15338767e-01,
#           1.04715455e+00, -6.83609918e-02, -9.31973219e-01,
#          -1.64578342e+00, -1.11741722e+00,  1.18217885e+00],
#         [-1.13413537e+00, -4.57849950e-01, -1.26054096e+00,
#          -7.47755170e-01,  9.77390170e-01, -6.37316287e-01,
#           1.58540142e+00, -1.56197083e+00,  1.26188964e-01,
#           2.36794233e+00,  1.58994719e-02, -2.10237336e+00,
#          -1.04153290e-01, -2.25071907e-01, -1.86749232e+00,
#          -2.29437232e+00, -1.52880931e+00,  1.51250255e+00,
#          -2.17204618e+00, -1.32882059e+00, -1.43050408e+00,
#           9.68445539e-01, -4.04277265e-01,  1.00071287e+00,
#           1.42235935e+00, -1.10405765e-01, -1.27352631e+00,
#          -2.31088400e+00, -1.51220846e+00,  1.55107164e+00],
#         [-6.27318174e-02, -6.04134761e-02, -6.50292113e-02,
#          -4.84815128e-02,  6.17962927e-02, -6.09359480e-02,
#           1.09560885e-01, -1.33092284e-01, -3.20227481e-02,
#           1.45955712e-01, -1.21391732e-02, -1.30658969e-01,
#           2.23495234e-02,  7.39017967e-03, -1.23751067e-01,
#          -1.27642706e-01, -1.14754230e-01,  1.10956907e-01,
#          -1.17992558e-01, -9.06018019e-02, -8.66617858e-02,
#           7.79276863e-02, -2.36244835e-02,  5.05665392e-02,
#           8.60493705e-02,  2.35271603e-02, -8.40391666e-02,
#          -1.46192968e-01, -1.08337574e-01,  9.57573578e-02],
#         [-1.16510081e+00, -6.83321297e-01, -1.24361837e+00,
#          -8.27056050e-01,  8.03149641e-01, -7.73558319e-01,
#           1.68340194e+00, -1.77365625e+00, -2.21437290e-01,
#           2.30795550e+00, -1.66986331e-01, -2.30350280e+00,
#           1.72101066e-01,  4.03791070e-02, -1.75427425e+00,
#          -2.08081913e+00, -1.62761772e+00,  1.69103980e+00,
#          -1.92349410e+00, -1.37033069e+00, -1.49856615e+00,
#           1.04754090e+00, -3.22024345e-01,  9.96050179e-01,
#           1.25394118e+00,  9.49124899e-03, -1.37862992e+00,
#          -2.43122983e+00, -1.70309639e+00,  1.51267123e+00],
#         [-2.49455437e-01, -1.36923388e-01, -2.34583497e-01,
#          -1.44558564e-01,  1.87434331e-01, -1.36617228e-01,
#           3.15587789e-01, -3.48706335e-01, -1.33921942e-02,
#           4.74310786e-01, -2.07458679e-02, -3.71836632e-01,
#           1.84731223e-02, -3.48057523e-02, -3.42213422e-01,
#          -4.61238205e-01, -2.97495753e-01,  3.31145197e-01,
#          -3.88111770e-01, -2.85838306e-01, -3.17172199e-01,
#           2.18502015e-01, -8.60024020e-02,  2.11276755e-01,
#           2.83274800e-01,  1.58869885e-02, -2.39551812e-01,
#          -4.30052042e-01, -3.13404948e-01,  2.60409057e-01],
#         [-1.33282638e+00, -1.01495969e+00, -1.19913924e+00,
#          -9.08113062e-01,  8.63999367e-01, -1.03317618e+00,
#           1.76953053e+00, -2.03076601e+00, -4.92585480e-01,
#           2.54639506e+00, -3.31736177e-01, -2.17136788e+00,
#           3.23785275e-01,  1.89096615e-01, -1.82166505e+00,
#          -1.98930526e+00, -1.89813292e+00,  1.91303957e+00,
#          -1.71438932e+00, -1.70589352e+00, -1.69869721e+00,
#           1.08475626e+00, -3.72628987e-01,  1.02192664e+00,
#           1.24862587e+00,  2.80928999e-01, -1.38329029e+00,
#          -2.49795556e+00, -1.79777682e+00,  1.31160343e+00],
#         [-7.07441568e-02, -5.01859747e-02, -5.87771907e-02,
#          -3.57582234e-02,  4.63244654e-02, -4.77110147e-02,
#           6.04506880e-02, -9.51296315e-02, -2.87973806e-02,
#           1.15370452e-01, -6.65983837e-03, -9.76116732e-02,
#           2.58695241e-02, -8.57183244e-03, -7.99594298e-02,
#          -9.54937637e-02, -6.07833080e-02,  9.12084132e-02,
#          -6.96503222e-02, -5.66804744e-02, -6.06822595e-02,
#           3.94672230e-02, -2.74884682e-02,  4.67211530e-02,
#           5.05786464e-02, -3.99259944e-03, -6.10592626e-02,
#          -8.68966579e-02, -6.73574656e-02,  6.20541275e-02],
#         [-1.07183003e+00, -1.69234700e-03, -1.28575432e+00,
#          -6.60598576e-01,  9.45343196e-01, -1.94241658e-01,
#           1.54724336e+00, -1.27931249e+00,  5.75074792e-01,
#           2.19193840e+00,  2.52034515e-01, -2.49366689e+00,
#          -3.91161680e-01, -5.43481171e-01, -1.82254779e+00,
#          -2.54014349e+00, -1.30179405e+00,  1.11600983e+00,
#          -2.61410356e+00, -9.61574674e-01, -1.27499807e+00,
#           9.86909688e-01, -4.02682900e-01,  8.72045100e-01,
#           1.48990095e+00, -5.84706426e-01, -1.26830053e+00,
#          -2.26867533e+00, -1.47027659e+00,  1.95947564e+00],
#         [-4.06017989e-01, -1.94032326e-01, -4.32693422e-01,
#          -2.82316476e-01,  3.02300245e-01, -2.12113440e-01,
#           5.56905925e-01, -5.90047717e-01, -6.16073329e-03,
#           8.27474713e-01, -2.14028470e-02, -8.10789824e-01,
#           2.80238129e-02, -4.85358573e-02, -6.46587908e-01,
#          -7.63626814e-01, -5.81201494e-01,  5.33785403e-01,
#          -7.17295825e-01, -4.82757270e-01, -5.21498382e-01,
#           3.61163527e-01, -1.12461686e-01,  3.38726699e-01,
#           4.61193115e-01, -2.45815217e-02, -4.60951954e-01,
#          -8.45538437e-01, -5.58813572e-01,  5.70740461e-01],
#         [-1.40878487e+00, -1.04318416e+00, -1.24377942e+00,
#          -8.65739226e-01,  8.45098376e-01, -1.02864540e+00,
#           1.76101291e+00, -2.13786674e+00, -6.59915805e-01,
#           2.60936761e+00, -3.38615954e-01, -2.22985339e+00,
#           3.21282297e-01,  2.13086560e-01, -1.76056159e+00,
#          -2.08890986e+00, -1.80836213e+00,  2.07423139e+00,
#          -1.73233342e+00, -1.65303588e+00, -1.74446189e+00,
#           1.21574330e+00, -4.20867085e-01,  1.10735321e+00,
#           1.30006254e+00,  3.27182502e-01, -1.41315222e+00,
#          -2.53821874e+00, -1.91671216e+00,  1.37723768e+00],
#         [-2.60200322e-01, -1.47181004e-01, -2.51360059e-01,
#          -1.85090467e-01,  1.69214159e-01, -1.47001222e-01,
#           3.36714029e-01, -3.83669823e-01, -5.21303266e-02,
#           5.11080146e-01, -3.81620899e-02, -4.72910196e-01,
#           1.79416349e-03, -3.69855156e-03, -3.64584267e-01,
#          -4.50384170e-01, -3.37411046e-01,  3.49846125e-01,
#          -3.96614164e-01, -2.97336251e-01, -3.32512856e-01,
#           2.30888590e-01, -9.62085202e-02,  2.01074570e-01,
#           2.68549979e-01, -2.35025561e-03, -2.89885432e-01,
#          -5.16210318e-01, -3.42389435e-01,  3.26964349e-01],
#         [-1.24874508e+00, -8.35866868e-01, -1.20791078e+00,
#          -8.51474106e-01,  7.29071319e-01, -7.39030421e-01,
#           1.62669742e+00, -1.94375765e+00, -5.42482734e-01,
#           2.38263226e+00, -2.98356473e-01, -2.47499228e+00,
#           1.52361020e-01,  1.43591076e-01, -1.62675118e+00,
#          -1.92116821e+00, -1.52199459e+00,  1.84234595e+00,
#          -1.79462540e+00, -1.28822303e+00, -1.60672557e+00,
#           1.14720869e+00, -3.01510304e-01,  1.06635237e+00,
#           1.15248930e+00,  9.63630602e-02, -1.41342819e+00,
#          -2.43161368e+00, -1.84416354e+00,  1.49075603e+00],
#         [-1.12549472e+00, -6.59772396e-01, -1.09484208e+00,
#          -7.78137505e-01,  7.30184793e-01, -7.37134695e-01,
#           1.53908658e+00, -1.67433679e+00, -3.13200504e-01,
#           2.12098622e+00, -1.71674669e-01, -2.21510911e+00,
#           1.31860480e-01,  3.82832550e-02, -1.56270278e+00,
#          -1.87003863e+00, -1.46725571e+00,  1.54636705e+00,
#          -1.72188389e+00, -1.20392334e+00, -1.41165876e+00,
#           1.00216436e+00, -2.95870483e-01,  9.35341537e-01,
#           1.10567927e+00,  6.30084127e-02, -1.24798191e+00,
#          -2.19012141e+00, -1.62564480e+00,  1.37788355e+00]], dtype=float32),
#  (23, 30))

# %%
# 試しに類似文書抽出
for i in range(3):
    print('==========================')
    print("文書A＝",''.join(word_list[i]))
    print()
    print("文書B＝",model.docvecs.most_similar(i)[0][0].replace('"','').replace('[','').replace(']','').replace("'","").replace(',','').replace(' ',''))
    print()
# Out:
# ==========================
# 文書A＝ 一
# うとうととして目がさめると女はいつのまにか、隣のじいさんと話を始めている
#
# 文書B＝ 文芸は技術でもない、事務でもない
#
# ==========================
# 文書A＝ このじいさんはたしかに前の前の駅から乗ったいなか者である
#
# 文書B＝ 三四郎はしばらく我慢していたが、とうとう焦れったくなって、与次郎に、美禰子に関するすべての事実を隠さずに話してくれと請求した
#
# ==========================
# 文書A＝ 発車まぎわに頓狂な声を出して駆け込んで来て、いきなり肌をぬいだと思ったら背中にお灸のあとがいっぱいあったので、三四郎の記憶に残っている
#
# 文書B＝ やがてまた動く気になったので腰を上げて、立ちながら靴の踵を向け直すと、丘の上りぎわの、薄く色づいた紅葉の間に、さっきの女の影が見えた

# %%
print("文書A＝",''.join(word_list[0]))
print()
print("文書B＝",''.join(word_list[100]))
print()
print("類似度",model.docvecs.similarity(0,100))
# Out:
# 文書A＝ 一
# うとうととして目がさめると女はいつのまにか、隣のじいさんと話を始めている
#
# 文書B＝ うしろから女がついて来る
#
# 類似度 -0.12957396

# %% [markdown]
# # 実際の使い方
#
# word2vecもdoc2vecも
#
# NNなどの各種機械学習アルゴリズムで、自然言語を利用しようと思うと、自然言語の数値化は必須です。
#
# その為、自然言語解析のベースとなるアルゴリズムです。
#
# 似た意味を持つ単語や「単語の意味」の加算減算することにより、類似した単語や文章の抽出が可能です。
#
# 実務では、質問投稿サイトなどで、似通った質問のレコメンドシステムや検索エンジンの構築が出来ます。
